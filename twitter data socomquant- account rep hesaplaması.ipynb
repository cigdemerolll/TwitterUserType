# %%
import json

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
a = pd.read_json("/Users/cigdemerol/Desktop/fixedDataCigdem1.json")

# %%
data = pd.DataFrame.from_dict(a, orient = "columns")

# %%
data
# Out:
#                         id               id_str                  name  \
# 0      1377260947631398913  1377260947631398912               Taha Öz
# 1                820100095            820100095           Ferda Çevik
# 2      1377257157888987141  1377257157888987136  cburakucar@gmail.com
# 3       906047018522599424   906047018522599424         Gökhan Taneri
# 4      1375898544897425415  1375898544897425408                 Musti
# ...                    ...                  ...                   ...
# 14474           2235189010           2235189010                Suzars
# 14475  1364433456994910212  1364433456994910208                Gökhan
# 14476  1362245523110043648  1362245523110043648                 Harun
# 14477  1364255357397331968  1364255357397331968           Filiz Özkan
# 14478  1364847746386169857  1364847746386169856               İbrahim
#
#            screen_name location                description   url  \
# ...

# %%
np_location = np.array(data.loc[ : , ["location"]])

# %%
print(np_location)
# Out:
# [['']
#  ['']
#  ['']
#  ...
#  ['']
#  ['']
#  ['']]

# %%
type(np_location)
# Out:
# numpy.ndarray

# %%
for i in np_location :
    print(i)
# Out:
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['Ankara-Adana/Türkiye']
# ['Ankara, Türkiye']
# ['Ardahan, Türkiye']
# ['']
# ['']
# ['İzmir, Türkiye']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['İstanbul, Türkiye']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['Ardeşen, Rize']
# ['']
# ['İzmir, Türkiye']
# ['Eskişehir, Türkiye']
# ['']
# ['']
# ['İstanbul, Türkiye']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['Ankara, İstanbul']
# ['']
# ['favela']
# ['']
# ['Konya, Adana, Türkiye']
# ['']
# ['']
# ['']
# ['Balabanağa, İstanbul']
# ['']
# ['']
# ['']
# ['']
# ['Adana']
# ['']
# ['']
# ['Trabzon, Türkiye']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['Göztepe, İzmir']
# ['Kocaeli, Türkiye']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['Bursa, Türkiye']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['samsun']
# ['']
# ['Trabzon, Türkiye']
# ['']
# ['🦄']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['yozgat']
# ...

# %%
data.loc[ : , ["location"]]
# Out:
#       location
# 0
# 1
# 2
# 3
# 4
# ...        ...
# 14474
# 14475
# 14476
# 14477
# 14478
#
# [14479 rows x 1 columns]

# %%
data['account_rep'] = data['followers_count']/(data['friends_count'] + data['followers_count'])

# %%
data.loc[:,'account_rep']
# Out:
# 0        0.000000
# 1        0.272000
# 2        0.008000
# 3        0.045249
# 4        0.127273
#            ...
# 14474    0.025316
# 14475    0.066667
# 14476    0.000000
# 14477    0.020408
# 14478    0.068966
# Name: account_rep, Length: 14479, dtype: float64

# %%
for id, row in data.iterrows():
    
    if 'account_rep' <= '0.5' :
     print ("low_rep")
    
    else :
     print("high_rep")
# Out:
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# high_rep
# ...

# %%
high_rep = data['account_rep'] >= 0.5

# %%
data[high_rep]
# Out:
#                         id               id_str               name  \
# 15               472879716            472879716        Mehmet Aycı
# 16     1376830813984194561  1376830813984194560         Ghost Soul
# 19              2583636492           2583636492               uğur
# 34              2343662993           2343662993             şefika
# 45      962287316399206401   962287316399206400        Divan Kitap
# ...                    ...                  ...                ...
# 14140           2604902041           2604902041   Terzi Rıza Akbaş
# 14216  1243202351344898050  1243202351344898048             BİNGÜL
# 14287            187554120            187554120  RECEP BÜYÜKBAYRAK
# 14372            237899712            237899712       Serhan ABACI
# 14445            265086984            265086984           Chekic ツ
#
#           screen_name              location  \
# 15         Mehmetayci  Ankara-Adana/Türkiye
# 16       soulpassion_       Ankara, Türkiye
# 19          ozklcugur
# ...

# %%
low_rep = data['account_rep'] <= 0.5

# %%
data[low_rep]
# Out:
#                         id               id_str                  name  \
# 0      1377260947631398913  1377260947631398912               Taha Öz
# 1                820100095            820100095           Ferda Çevik
# 2      1377257157888987141  1377257157888987136  cburakucar@gmail.com
# 3       906047018522599424   906047018522599424         Gökhan Taneri
# 4      1375898544897425415  1375898544897425408                 Musti
# ...                    ...                  ...                   ...
# 14474           2235189010           2235189010                Suzars
# 14475  1364433456994910212  1364433456994910208                Gökhan
# 14476  1362245523110043648  1362245523110043648                 Harun
# 14477  1364255357397331968  1364255357397331968           Filiz Özkan
# 14478  1364847746386169857  1364847746386169856               İbrahim
#
#            screen_name location                description   url  \
# ...

# %%
plt.hist(data['account_rep'], bins = 10)
plt.show()

# %%
data.iloc[ 1, :]
# Out:
# id                                                                            820100095
# id_str                                                                        820100095
# name                                                                        Ferda Çevik
# screen_name                                                             ferdaismancevik
# location
# description
# url                                                                                None
# entities                                                  {'description': {'urls': []}}
# protected                                                                         False
# followers_count                                                                      34
# friends_count                                                                        91
# listed_count                                                                          0
# ...
